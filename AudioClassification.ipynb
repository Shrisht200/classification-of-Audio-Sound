# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.26.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (4.8.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.0->librosa) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shweta budhiraja\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
filename='UrbanSound8K/dog_bark.wav'
data, sample_rate = librosa.load(filename)

# %%
# !dir
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is A260-13F0
#
#  Directory of D:\Classification of Audio Sound
#
# 13-03-2024  22:04    <DIR>          .
# 13-03-2024  21:38    <DIR>          .ipynb_checkpoints
# 13-03-2024  22:04            22,785 AudioClassification.ipynb
# 13-03-2024  21:40    <DIR>          UrbanSound8K
#                1 File(s)         22,785 bytes
#                3 Dir(s)  236,568,870,912 bytes free

# %%
### Dog Sound
plt.figure(figsize=(14, 5))
plt.plot(data)
plt.title('Waveform')
plt.xlabel('Sample')
plt.ylabel('Amplitude')
plt.show()
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
import pandas as pd

metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64
